# %%
import numpy as np
import pandas as pd
from scipy.stats import uniform, binom, norm, kstest
import scipy.stats as st
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Asus\miniconda3\envs\edu\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['norm', 'uniform']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# ## Тест Колмогорова-Смирнова
# H0: x взята из генеральной совокупности с распределением F
#
# H1: x взята из генеральной совокупности с другим распределением

# %%
np.random.seed(42)

# %%
x = st.norm.rvs(size=1000, loc = 0, scale = 1)

# %%
plt.hist(x, bins=30)
# Out:
# (array([  1.,   0.,   3.,   3.,   6.,  13.,  19.,  37.,  40.,  55.,  75.,
#          98.,  76.,  94., 102.,  86.,  84.,  56.,  45.,  31.,  28.,  23.,
#          12.,   3.,   7.,   1.,   1.,   0.,   0.,   1.]),
#  array([-3.24126734, -3.00480071, -2.76833408, -2.53186746, -2.29540083,
#         -2.0589342 , -1.82246757, -1.58600095, -1.34953432, -1.11306769,
#         -0.87660106, -0.64013444, -0.40366781, -0.16720118,  0.06926545,
#          0.30573208,  0.5421987 ,  0.77866533,  1.01513196,  1.25159859,
#          1.48806521,  1.72453184,  1.96099847,  2.1974651 ,  2.43393172,
#          2.67039835,  2.90686498,  3.14333161,  3.37979824,  3.61626486,
#          3.85273149]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# Сравним нормальное с нормальным

# %%
kstest(x, "norm")
# Out:
# KstestResult(statistic=0.026193486856562198, pvalue=0.49836701373438425)

# %% [markdown]
# Сравним нормальное с экспоненциальным

# %%
kstest(x, "expon")
# Out:
# KstestResult(statistic=0.49, pvalue=6.358163602874007e-222)

# %% [markdown]
# Сравним нормальное с биномиальным

# %%
kstest(x, "binom", args=(1500, 0.16))
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %% [markdown]
# ## QQ-plot

# %%
st.probplot(x, dist="norm", plot=pylab)
# Out:
# ((array([-3.19758950e+00, -2.93237785e+00, -2.78437841e+00, -2.67999560e+00,
#          -2.59855946e+00, -2.53139899e+00, -2.47402263e+00, -2.42379214e+00,
#          -2.37902149e+00, -2.33856546e+00, -2.30160949e+00, -2.26755284e+00,
#          -2.23593934e+00, -2.20641415e+00, -2.17869564e+00, -2.15255643e+00,
#          -2.12781017e+00, -2.10430217e+00, -2.08190261e+00, -2.06050135e+00,
#          -2.04000420e+00, -2.02032992e+00, -2.00140792e+00, -1.98317650e+00,
#          -1.96558137e+00, -1.94857451e+00, -1.93211325e+00, -1.91615948e+00,
#          -1.90067901e+00, -1.88564107e+00, -1.87101783e+00, -1.85678408e+00,
#          -1.84291686e+00, -1.82939524e+00, -1.81620005e+00, -1.80331371e+00,
#          -1.79072004e+00, -1.77840415e+00, -1.76635224e+00, -1.75455157e+00,
#          -1.74299028e+00, -1.73165738e+00, -1.72054262e+00, -1.70963644e+00,
#          -1.69892989e+00, -1.68841463e+00, -1.67808281e+00, -1.66792707e+00,
# ...

# %%
y = st.expon.rvs(size=1500, loc = 0, scale = 1)
st.probplot(y, dist="norm", plot=pylab)
# Out:
# ((array([-3.31270533, -3.05604344, -2.91334469, ...,  2.91334469,
#           3.05604344,  3.31270533]),
#   array([1.34702076e-04, 1.35454269e-03, 1.56633125e-03, ...,
#          6.12882299e+00, 6.40547288e+00, 7.44172291e+00])),
#  (0.9038606561666691, 0.9990196615497087, 0.9038846368136965))

# %%
z = st.binom.rvs(size=1500, n=1500, p=0.16)
st.probplot(z, dist="norm", plot=pylab)
# Out:
# ((array([-3.31270533, -3.05604344, -2.91334469, ...,  2.91334469,
#           3.05604344,  3.31270533]),
#   array([179, 194, 195, ..., 279, 283, 283])),
#  (14.341927295520938, 239.57266666666666, 0.9988952446619549))
